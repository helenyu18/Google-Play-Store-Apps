# %% [markdown]
# # Group 5

# %% [markdown]
# ### Quanlei Chi (qc2246)，Qinyuan Lu (ql2344)，Helen Yu (wy2314) ，Xueqing Zhang (xz2719)，Shejie Zhao (sz2761)

# %%
import pandas as pd
import numpy as np
from pylab import rcParams
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import *
from sklearn.kernel_ridge import *
from sklearn.svm import *

# %%
df=pd.read_csv('googleplaystore.csv', encoding = "ISO-8859-1")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#eliminate duplicates for "App" 
df= df.drop_duplicates(subset = 'App', keep = 'first')
print(df.shape)
df.head()
# Out:
# (9660, 13)
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#drop the Column "Genres", cause it is similar to "Category"
df.drop('Genres', axis= 1, inplace= True)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating      Last Updated  \
# 0     159   19M      10,000+  Free     0       Everyone   January 7, 2018
# 1     967   14M     500,000+  Free     0       Everyone  January 15, 2018
# 2   87510  8.7M   5,000,000+  Free     0       Everyone    August 1, 2018
# 3  215644   25M  50,000,000+  Free     0           Teen      June 8, 2018
# 4     967  2.8M     100,000+  Free     0       Everyone     June 20, 2018
#
#           Current Ver   Android Ver
# 0               1.0.0  4.0.3 and up
# 1               2.0.0  4.0.3 and up
# 2               1.2.4  4.0.3 and up
# 3  Varies with device    4.2 and up
# 4                 1.1    4.4 and up

# %%
df.shape
# Out:
# (9660, 12)

# %%
#count missing vaues in each column
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#drop rows with missing value
df = df.dropna(how = 'any')
df.shape
# Out:
# (8190, 12)

# %%
#check data types
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#Rating distribution
df['Rating'].describe()
# Out:
# count    8190.000000
# mean        4.173321
# std         0.536691
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
#Start deal with "category" column
df.Category.value_counts()
# Out:
# FAMILY                 1607
# GAME                    912
# TOOLS                   717
# FINANCE                 302
# LIFESTYLE               301
# PRODUCTIVITY            301
# PERSONALIZATION         296
# MEDICAL                 290
# BUSINESS                263
# PHOTOGRAPHY             263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           60
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# Name: Category, dtype: int64

# %%
#Start deal with "Installs" column
df.Installs.value_counts()
# Out:
# 1,000,000+        1414
# 100,000+          1094
# 10,000+            986
# 10,000,000+        937
# 1,000+             696
# 5,000,000+         607
# 500,000+           503
# 50,000+            456
# 5,000+             424
# 100+               303
# 50,000,000+        202
# 500+               199
# 100,000,000+       188
# 10+                 69
# 50+                 56
# 500,000,000+        24
# 1,000,000,000+      20
# 5+                   9
# 1+                   3
# Name: Installs, dtype: int64

# %%
#Rating distribution
df['Installs'].describe()
# Out:
# count           8190
# unique            19
# top       1,000,000+
# freq            1414
# Name: Installs, dtype: object

# %%
#Start deal with "Type" column
df.Type.value_counts()
# Out:
# Free    7588
# Paid     602
# Name: Type, dtype: int64

# %% [markdown]
# # Changing Categorical Variables into Numeric

# %% [markdown]
# ### Columns - Size & Installs

# %%
len(df[df.Size == 'Varies with device'])
# change it to NA first

df['Size'].replace('Varies with device', np.nan, inplace = True ) 
df.Size = (df.Size.replace(r'[kM]+$', '', regex=True).astype(float) * \
            df.Size.str.extract(r'[\d\.]+([KM]+)', expand=False)
            .fillna(1)
            .replace(['k','M'], [10**3, 10**6]).astype(int))
df['Size'].fillna(df.groupby('Category')['Size'].transform('mean'),inplace = True)

# %%
df.Installs = df.Installs.apply(lambda x: x.replace(',',''))
df.Installs = df.Installs.apply(lambda x: x.replace('+',''))
df.Installs = df.Installs.apply(lambda x: int(x))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size  Installs  Type Price Content Rating      Last Updated  \
# 0     159  19000000.0     10000  Free     0       Everyone   January 7, 2018
# 1     967  14000000.0    500000  Free     0       Everyone  January 15, 2018
# 2   87510   8700000.0   5000000  Free     0       Everyone    August 1, 2018
# 3  215644  25000000.0  50000000  Free     0           Teen      June 8, 2018
# 4     967   2800000.0    100000  Free     0       Everyone     June 20, 2018
#
#           Current Ver   Android Ver
# 0               1.0.0  4.0.3 and up
# 1               2.0.0  4.0.3 and up
# 2               1.2.4  4.0.3 and up
# 3  Varies with device    4.2 and up
# 4                 1.1    4.4 and up

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### Column - Reviews

# %%
# convert to int

df['Reviews'] = df['Reviews'].apply(lambda x: int(x))

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### Column - Price

# %%
df['Price'].value_counts().head(30)
# Out:
# 0          7588
# $2.99       109
# $0.99       103
# $4.99        68
# $1.99        59
# $3.99        52
# $1.49        30
# $2.49        20
# $9.99        14
# $5.99        14
# $399.99      11
# $6.99        11
# $4.49         9
# $14.99        8
# $3.49         7
# $7.99         7
# $29.99        4
# $8.99         4
# $12.99        4
# $19.99        4
# $11.99        3
# $10.99        2
# $17.99        2
# $1.70         2
# $10.00        2
# $1.00         2
# $24.99        2
# $16.99        2
# $5.49         2
# $7.49         2
# Name: Price, dtype: int64

# %%
df.Price = df.Price.apply(lambda x: x.replace('$',''))
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# #### Column - Category

# %%
df.Category = pd.Categorical(df.Category)

# %%
df['Category_num'] = df.Category.astype('category').cat.codes

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size  Installs  Type  Price Content Rating  \
# 0      159  19000000.0     10000  Free    0.0       Everyone
# 1      967  14000000.0    500000  Free    0.0       Everyone
# 2    87510   8700000.0   5000000  Free    0.0       Everyone
# 3   215644  25000000.0  50000000  Free    0.0           Teen
# 4      967   2800000.0    100000  Free    0.0       Everyone
#
#        Last Updated         Current Ver   Android Ver  Category_num
# 0   January 7, 2018               1.0.0  4.0.3 and up             0
# 1  January 15, 2018               2.0.0  4.0.3 and up             0
# 2    August 1, 2018               1.2.4  4.0.3 and up             0
# 3      June 8, 2018  Varies with device    4.2 and up             0
# 4     June 20, 2018                 1.1    4.4 and up             0

# %%
df.dtypes
# Out:
# App                 object
# Category          category
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price              float64
# Content Rating      object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Category_num          int8
# dtype: object

# %%
df['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,        100,        500,
#                10,          5,         50,          1])

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Rating

# %%
#Area chart for distribution
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(df.Rating, color="Red", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
# Out:
# Text(0.5,1,'Distribution of Rating')

# %% [markdown]
# ##### Finding: Rating of 4.5 has the highest frequency in Google Play Store.
# ##### The average rating is around 4, which is high.

# %% [markdown]
# ### Category

# %%
print( len(df['Category'].unique()) , "categories")

print("\n", df['Category'].unique())
# Out:
# 33 categories
#
#  [ART_AND_DESIGN, AUTO_AND_VEHICLES, BEAUTY, BOOKS_AND_REFERENCE, BUSINESS, ..., PARENTING, WEATHER, VIDEO_PLAYERS, NEWS_AND_MAGAZINES, MAPS_AND_NAVIGATION]
# Length: 33
# Categories (33, object): [ART_AND_DESIGN, AUTO_AND_VEHICLES, BEAUTY, BOOKS_AND_REFERENCE, ..., WEATHER, VIDEO_PLAYERS, NEWS_AND_MAGAZINES, MAPS_AND_NAVIGATION]

# %%
g = sns.countplot(x="Category",data=df, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of app in each category',size = 20)
# Out:
# Text(0.5,1,'Count of app in each category')

# %% [markdown]
# ##### Finding: Application in category of "Family", "Game", and "Tools" have highest counts in Google Play Store.

# %% [markdown]
# ### Review

# %%
df['Reviews'] = df['Reviews'].apply(lambda x: int(x))

# %%
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(df.Reviews, color="Green", shade = True)
g.set_xlabel("Reviews")
g.set_ylabel("Frequency")
plt.title('Distribution of Reveiw',size = 20)
# Out:
# Text(0.5,1,'Distribution of Reveiw')

# %% [markdown]
# ##### Findings: Most of application in Google Play Store have less than 1M reviews.

# %% [markdown]
# ### Type

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
#Pie chart to show the percentage
labels =df['Type'].value_counts(sort = True).index
sizes = df['Type'].value_counts(sort = True)


colors = ["palegreen","orangered"]
explode = (0.1,0)  # explode 1st slice
 
rcParams['figure.figsize'] = 8,8
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=270,)

plt.title('Percent of Free App in store',size = 20)
plt.show()

# %% [markdown]
# ##### Finding: 92.6% application in Google Play Store is free. 7.6% application are paid.

# %%
df.Price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
df['Price'].value_counts().head(30)
# Out:
# 0.00      7588
# 2.99       109
# 0.99       103
# 4.99        68
# 1.99        59
# 3.99        52
# 1.49        30
# 2.49        20
# 5.99        14
# 9.99        14
# 399.99      11
# 6.99        11
# 4.49         9
# 14.99        8
# 7.99         7
# 3.49         7
# 29.99        4
# 8.99         4
# 19.99        4
# 12.99        4
# 11.99        3
# 1.70         2
# 10.00        2
# 1.00         2
# 24.99        2
# 7.49         2
# 10.99        2
# 16.99        2
# 17.99        2
# 5.49         2
# Name: Price, dtype: int64

# %%
df_price = df.loc[df['Price'] > 0]

# %%
rcParams['figure.figsize'] = 15.7,8.27
g = sns.countplot(x=df_price['Price'],data=df_price, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('Count of paid app in each price',size = 20)
# Out:
# Text(0.5,1,'Count of paid app in each price')

# %% [markdown]
# #### For the paid app, 2.99 dollar, 0.99 dollar and 4.99 dollar are top first three common price

# %% [markdown]
# ### Install

# %%
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(df.Installs, color="Purple", shade = True)
g.set_xlabel("Install")
g.set_ylabel("Frequency")
plt.title('Distribution of Install',size = 20)
# Out:
# Text(0.5,1,'Distribution of Install')

# %% [markdown]
# #### 1,000,000+ are most common install

# %% [markdown]
# # Correlation Matrix

# %%
df_t = df[['Rating', 'Reviews','Size','Installs','Price','Category_num']]
df_t.head()
# Out:
#    Rating  Reviews        Size  Installs  Price  Category_num
# 0     4.1      159  19000000.0     10000    0.0             0
# 1     3.9      967  14000000.0    500000    0.0             0
# 2     4.7    87510   8700000.0   5000000    0.0             0
# 3     4.5   215644  25000000.0  50000000    0.0             0
# 4     4.3      967   2800000.0    100000    0.0             0

# %%
df_t.dtypes
# Out:
# Rating          float64
# Reviews           int64
# Size            float64
# Installs          int64
# Price           float64
# Category_num       int8
# dtype: object

# %%
df_part = df_t.loc[df['Reviews'] < 1000000]
df_part.shape
# Out:
# (7841, 6)

# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
import  matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
# Out:
# /Users/Xueqing/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import seaborn as sns

# Compute the correlation matrix

corr = df_t.corr()
sns.set(style="whitegrid")

# Generate a mask for the upper triangle
mask_ur = np.zeros_like(corr, dtype=np.bool)
mask_ur[np.triu_indices_from(mask_ur)] = True

# Set up the figure
fig_corr, axs_corr = plt.subplots(figsize=(11,9))

# Draw the heatmap with mask
sns.heatmap(corr, mask=mask_ur, cmap="coolwarm")

# %% [markdown]
# ##### We can observe the relationship between rating and other variables in the correlation matrix. For overall dataset, price, number of installs, size and previews are not really correlated to rating.

# %%
plt.figure(figsize = (10,10))
sns.regplot(x="Reviews", y="Rating", color = 'Green',data=df[df['Reviews']<1000000]);
plt.title('Rating VS Reveiws',size = 20)
# Out:
# Text(0.5,1,'Rating VS Reveiws')

# %% [markdown]
# ##### Most of application in this store have less than 1M in reviews.
# ##### Seem like well-known application will get a good rating.

# %%
plt.figure(figsize = (10,10))
sns.regplot(x="Installs", y="Rating", color = 'teal',data=df_t);
plt.title('Rating VS Installs',size = 20)
# Out:
# Text(0.5,1,'Rating VS Installs')

# %% [markdown]
# ##### Seem like number of install has little affect to rating.

# %%
plt.figure(figsize = (10,10))
sns.regplot(x="Size", y="Rating", color = 'orangered',data=df_t);
plt.title('Rating VS Size',size = 20)
# Out:
# Text(0.5,1,'Rating VS Size')

# %% [markdown]
# ##### Seem like number of size has little affect to rating.

# %%
#Boxplot for outlines
g = sns.catplot(x="Category",y="Rating",data=df, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Rating")
plt.title('Boxplot of Rating VS Category',size = 20)
# Out:
# Text(0.5,1,'Boxplot of Rating VS Category')

# %% [markdown]
# ##### Finding: Rating of each category is not different too much.

# %% [markdown]
# # Regression analysis

# %%
#to add into results_index for evaluation of error term 
from sklearn import metrics
def Evaluationmatrix_dict(y_true, y_predict, name = 'Linear'):
    dict_matrix = {}
    dict_matrix['Series Name'] = name
    dict_matrix['Mean Squared Error'] = metrics.mean_squared_error(y_true,y_predict)
    dict_matrix['Mean Absolute Error'] = metrics.mean_absolute_error(y_true,y_predict)
    dict_matrix['Mean Squared Log Error'] = metrics.mean_squared_log_error(y_true,y_predict)
    return dict_matrix

resultsdf = pd.DataFrame()

# %%
X = df_t.values[:, 1:5]
Y = df_t.values[:,0]

# %%
# split dataset with train & test
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3, random_state = 100)

# %%
# for high rating
#For Rating > 4
df_part = df_t.loc[df['Rating'] > 4]
df_part = df_part.loc[df['Reviews'] < 1000000]
df_part.shape
# Out:
# (5429, 6)

# %%
# Compute the correlation matrix

corr = df_part.corr()
sns.set(style="whitegrid")

# Generate a mask for the upper triangle
mask_ur = np.zeros_like(corr, dtype=np.bool)
mask_ur[np.triu_indices_from(mask_ur)] = True

# Set up the figure
fig_corr, axs_corr = plt.subplots(figsize=(11,9))

# Draw the heatmap with mask
sns.heatmap(corr, mask=mask_ur, cmap="coolwarm")

# %%
Xp = df_part.values[:, 1:5]
Yp = df_part.values[:,0]

# %%
Xp_train, Xp_test, yp_train, yp_test = train_test_split( Xp, Yp, test_size = 0.3, random_state = 100)

# %% [markdown]
# # Linear Regression

# %%
#Linear Regression

# %%
ln = LinearRegression().fit(X_train, y_train)
ln.score(X_train, y_train)
# Out:
# 0.008256671900475854

# %%
result1 = ln.predict(X_test)

# %%
plt.figure(figsize=(12,7))
sns.regplot(result1,y_test,color='purple')
plt.title('Linear Regressor')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %%
resultsdf = resultsdf.append(Evaluationmatrix_dict(y_test,result1, name = 'Linear Regressor'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
#
#         Series Name
# 0  Linear Regressor

# %% [markdown]
# ### For high rating

# %%
ln = LinearRegression().fit(Xp_train, yp_train)
ln.score(Xp_train, yp_train)
# Out:
# 0.012036716732855335

# %%
result1b = ln.predict(Xp_test)

# %%
plt.figure(figsize=(12,7))
sns.regplot(result1b,yp_test,color='purple')
plt.title('Linear Regressor')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %%
resultsdf = resultsdf.append(Evaluationmatrix_dict(yp_test,result1b, 
                                                   name = 'Linear Regressor - High Rating'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
# 1             0.194916            0.056444                0.001875
#
#                       Series Name
# 0                Linear Regressor
# 1  Linear Regressor - High Rating

# %% [markdown]
# #### The mean accuracy value is very low, so move to next one.

# %% [markdown]
# # Decision Tree Regression

# %%
#decision Tree
regr1 = DecisionTreeRegressor(random_state = 100, max_depth=8, min_samples_leaf=4)
regr1.fit(X_train,y_train)
print ("Training score:%f"%(regr1.score(X_train,y_train)))
#print ("Test score:%f"%(regr1.score(X_test,y_test)))
# Out:
# Training score:0.213346

# %%
y_1 = regr1.predict(X_test)

# %%
d = {'col1': y_test, 'col2': y_1}

# %%
df_a = pd.DataFrame(data=d)
df_a['index_col'] = df_a.index

# %%
df_a
# Out:
#       col1      col2  index_col
# 0      4.2  4.260000          0
# 1      3.8  4.105536          1
# 2      4.3  4.566667          2
# 3      4.4  4.600000          3
# 4      4.4  3.997376          4
# 5      1.9  4.022802          5
# 6      3.7  4.175862          6
# 7      3.1  4.022802          7
# 8      4.5  4.064516          8
# 9      4.5  4.175862          9
# 10     4.0  4.175862         10
# 11     4.7  4.505479         11
# 12     4.3  4.184337         12
# 13     4.6  4.105536         13
# 14     3.1  3.997376         14
# 15     4.2  4.320635         15
# 16     4.3  4.105536         16
# 17     3.8  4.105536         17
# 18     3.4  4.562500         18
# 19     4.8  4.175862         19
# 20     4.1  4.184337         20
# 21     4.6  4.000000         21
# 22     4.0  4.242246         22
# 23     4.3  4.355000         23
# 24     3.7  4.400000         24
# 25     3.3  4.065116         25
# 26     3.7  3.997376         26
# 27     4.1  4.105536         27
# 28     4.5  4.536364         28
# 29     4.4  4.137778         29
# ...    ...       ...        ...
# 2427   3.2  4.074211       2427
# 2428   3.8  3.952361       2428
# 2429   3.9  3.997376       2429
# 2430   3.7  4.105536       2430
# 2431   3.7  4.074211       2431
# 2432   4.8  4.500000       2432
# 2433   4.8  4.227273       2433
# 2434   4.4  4.341463       2434
# 2435   4.3  3.997376       2435
# 2436   4.3  4.230000       2436
# 2437   4.5  4.242246       2437
# 2438   4.2  4.228947       2438
# 2439   3.6  3.784000       2439
# 2440   3.8  4.235965       2440
# 2441   4.4  3.997376       2441
# 2442   4.2  4.074211       2442
# 2443   4.3  4.536364       2443
# 2444   4.2  4.017949       2444
# 2445   4.3  4.017949       2445
# 2446   4.1  4.096190       2446
# 2447   3.5  3.952361       2447
# 2448   4.3  3.783333       2448
# 2449   4.2  4.293548       2449
# 2450   4.4  4.065116       2450
# 2451   4.7  4.320635       2451
# 2452   3.0  4.074211       2452
# 2453   4.8  4.017949       2453
# 2454   4.0  4.204000       2454
# 2455   4.3  4.341463       2455
# 2456   3.7  4.017949       2456
#
# [2457 rows x 3 columns]

# %%
plt.figure(figsize=(20, 16))
plt.scatter(df_a['index_col'], y_test, s=20, edgecolor="black",
            c="darkorange", label="Actual")
plt.plot(df_a['index_col'], y_1, color="cornflowerblue",
         label="predict", linewidth=2)
#plt.plot(df_a['index_col'], y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression", size = 20)
plt.legend(fontsize = 'xx-large',loc = 'lower right', shadow=True, bbox_to_anchor=(1, 1))
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_1)
# Out:
# 0.27410238511509655

# %%
plt.figure(figsize=(12,7))
sns.regplot(y_1,y_test,color='darkorange')
plt.title('Decision Tree Regressor')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %%
resultsdf = resultsdf.append(Evaluationmatrix_dict(y_test,y_1, name = 'Decision Tree Regressor'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
# 1             0.194916            0.056444                0.001875
# 2             0.361327            0.274102                0.014051
#
#                       Series Name
# 0                Linear Regressor
# 1  Linear Regressor - High Rating
# 2         Decision Tree Regressor

# %% [markdown]
# #### For High Rating App

# %%
#decision Tree
regr_part = DecisionTreeRegressor(random_state = 100, max_depth=25, min_samples_leaf=3)
regr_part.fit(Xp_train,yp_train)
print ("Training score:%f"%(regr_part.score(Xp_train,yp_train)))
#print ("Test score:%f"%(regr_part.score(X_test,y_test)))
# Out:
# Training score:0.706502

# %%
yp_1 = regr_part.predict(Xp_test)

# %%
dp = {'col1': yp_test, 'col2': yp_1}

# %%
df_p = pd.DataFrame(data=dp)
df_p['index_col'] = df_p.index
df_p
# Out:
#       col1      col2  index_col
# 0      4.3  4.425000          0
# 1      4.6  4.366667          1
# 2      4.4  4.366667          2
# 3      4.5  4.320000          3
# 4      4.3  4.300000          4
# 5      5.0  5.000000          5
# 6      4.5  4.680000          6
# 7      4.4  4.533333          7
# 8      4.2  4.433333          8
# 9      4.3  4.466667          9
# 10     4.2  4.400000         10
# 11     4.8  4.233333         11
# 12     4.8  4.700000         12
# 13     4.3  4.275000         13
# 14     4.2  4.300000         14
# 15     4.3  4.360000         15
# 16     4.2  4.320000         16
# 17     4.5  4.333333         17
# 18     4.4  4.400000         18
# 19     4.6  4.620000         19
# 20     4.2  4.250000         20
# 21     4.3  4.466667         21
# 22     4.3  4.725000         22
# 23     4.7  4.233333         23
# 24     4.3  4.266667         24
# 25     4.5  4.200000         25
# 26     4.3  4.260000         26
# 27     4.5  4.633333         27
# 28     4.3  4.175000         28
# 29     4.2  4.350000         29
# ...    ...       ...        ...
# 1599   4.5  4.400000       1599
# 1600   4.4  4.640000       1600
# 1601   4.3  4.391667       1601
# 1602   4.3  4.166667       1602
# 1603   4.5  4.400000       1603
# 1604   4.5  4.766667       1604
# 1605   4.5  4.133333       1605
# 1606   4.4  4.600000       1606
# 1607   4.4  4.600000       1607
# 1608   4.5  4.333333       1608
# 1609   4.8  4.233333       1609
# 1610   4.3  4.220000       1610
# 1611   5.0  4.933333       1611
# 1612   4.5  4.500000       1612
# 1613   4.7  4.466667       1613
# 1614   4.2  4.333333       1614
# 1615   4.5  4.150000       1615
# 1616   4.5  4.375000       1616
# 1617   4.3  4.600000       1617
# 1618   4.4  4.633333       1618
# 1619   4.4  4.340000       1619
# 1620   4.3  4.400000       1620
# 1621   4.7  4.766667       1621
# 1622   5.0  4.325000       1622
# 1623   4.2  4.300000       1623
# 1624   4.6  4.375000       1624
# 1625   4.4  4.320000       1625
# 1626   4.5  4.200000       1626
# 1627   4.1  4.366667       1627
# 1628   4.3  4.200000       1628
#
# [1629 rows x 3 columns]

# %%
plt.figure(figsize=(20, 16))
plt.scatter(df_p['index_col'], yp_test, s=20, edgecolor="black",
            c="darkorange", label="Actual")
plt.plot(df_p['index_col'], yp_1, color="cornflowerblue",
         label="predict", linewidth=2)
#plt.plot(df_a['index_col'], y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression", size = 20)
plt.legend(fontsize = 'xx-large',loc = 'lower right', shadow=True, bbox_to_anchor=(1, 1))
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.regplot(yp_1,yp_test,color='darkorange')
plt.title('Decision Tree Regressor for high rating')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %%
resultsdf = resultsdf.append(Evaluationmatrix_dict(yp_test,yp_1, name = 'Decision Tree Regressor-High rating'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
# 1             0.194916            0.056444                0.001875
# 2             0.361327            0.274102                0.014051
# 3             0.197998            0.061276                0.002062
#
#                            Series Name
# 0                     Linear Regressor
# 1       Linear Regressor - High Rating
# 2              Decision Tree Regressor
# 3  Decision Tree Regressor-High rating

# %% [markdown]
# #### The mean accuracy goes up a lot, especially for the High-rating side. However, errors go up little bit, goes to next model

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
model3 = RandomForestRegressor()
model3.fit(X_train,y_train)
Results3 = model3.predict(X_test)

# %%
#evaluation
resultsdf = resultsdf.append(Evaluationmatrix_dict(y_test,Results3, name = 'Random Forest Regressor'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
# 1             0.194916            0.056444                0.001875
# 2             0.361327            0.274102                0.014051
# 3             0.197998            0.061276                0.002062
# 4             0.387541            0.317810                0.015929
#
#                            Series Name
# 0                     Linear Regressor
# 1       Linear Regressor - High Rating
# 2              Decision Tree Regressor
# 3  Decision Tree Regressor-High rating
# 4              Random Forest Regressor

# %%
model3.score(X_train, y_train)
# Out:
# 0.7959684692421832

# %%
plt.figure(figsize=(12,7))
sns.regplot(Results3,y_test,color='teal', marker = 'x')
plt.title('Random Forest Regressor model')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %% [markdown]
# #### For high rating

# %%
model3b = RandomForestRegressor()
model3b.fit(Xp_train,yp_train)
Results3b = model3b.predict(Xp_test)

# %%
#evaluation
resultsdf = resultsdf.append(Evaluationmatrix_dict(yp_test,Results3b, name = 'Random Forest Regressor-High rating'),ignore_index = True)
resultsdf
# Out:
#    Mean Absolute Error  Mean Squared Error  Mean Squared Log Error  \
# 0             0.380414            0.297918                0.015127
# 1             0.194916            0.056444                0.001875
# 2             0.361327            0.274102                0.014051
# 3             0.197998            0.061276                0.002062
# 4             0.387541            0.317810                0.015929
# 5             0.177914            0.048538                0.001634
#
#                            Series Name
# 0                     Linear Regressor
# 1       Linear Regressor - High Rating
# 2              Decision Tree Regressor
# 3  Decision Tree Regressor-High rating
# 4              Random Forest Regressor
# 5  Random Forest Regressor-High rating

# %%
model3b.score(Xp_train, yp_train)
# Out:
# 0.8460220375182601

# %%
plt.figure(figsize=(12,7))
sns.regplot(Results3b,yp_test,color='teal', marker = '+')
plt.title('Random Forest Regressor model')
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.show()

# %% [markdown]
# ### Regression Result Conclusion

# %%
resultsdf.set_index('Series Name', inplace = True)

plt.figure(figsize = (10,12))
plt.subplot(3,1,1)
resultsdf['Mean Squared Error'].sort_values(ascending = False).plot(kind = 'barh',color=(0.3, 0.4, 0.6, 1), 
                                                                    title = 'Mean Squared Error')
plt.subplot(3,1,2)
resultsdf['Mean Absolute Error'].sort_values(ascending = False).plot(kind = 'barh',color=(0.5, 0.4, 0.6, 1), title = 'Mean Absolute Error')
plt.subplot(3,1,3)
resultsdf['Mean Squared Log Error'].sort_values(ascending = False).plot(kind = 'barh',color=(0.7, 0.4, 0.6, 1), title = 'Mean Squared Log Error')
plt.show()

# %% [markdown]
# #### Hard to conclude which is the best predictive accuracy
# #### Overall, the model for the high rating (rating >4) have more accuracy; And the Random Forest Regressor -  High rating have lowest error with high fit score.

# %% [markdown]
# # Natual Language Processing on Google Play Store User Reviews dataset

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read Data
Data=pd.read_csv("googleplaystore_user_reviews.csv",encoding="latin1")
Data.head(10)

Data.dropna(axis=0,inplace=True)

# %%
# See the distribution of the sentiment
sns.countplot(Data.Sentiment)
print(Data.Sentiment.value_counts())
plt.title("Count of Sentiments")
plt.show()
# Out:
# Positive    23998
# Negative     8271
# Neutral      5158
# Name: Sentiment, dtype: int64

# %% [markdown]
# ### From the plot we could know that most reviews are positive and nearly 1 in 4 reviews are negative

# %%
## See the sentiment score distribution by using scatter plot
plt.figure(figsize=(10,8))
j = sns.scatterplot(Data['Sentiment_Polarity'],Data['Sentiment_Subjectivity'],hue=Data['Sentiment'], edgecolor='pink',palette="plasma_r")
plt.xlabel('Sentiment Polarity', fontsize=20)
plt.ylabel('Sentiment Subjectivity', fontsize=20)
plt.title("Sentiment Analysis", fontsize=20)
plt.show()

# %%
Data=pd.concat([Data.Translated_Review,Data.Sentiment],axis=1)
Data.Sentiment=[0 if i=="Positive" else 1 if i== "Negative" else 2 for i in Data.Sentiment]

# %%
#Data cleaning
#Here we will remove characters which are not letters. ":) # $ @ ()!-/*" like that!
#Also converting them lower case.
import re
first_text=Data.Translated_Review[0]
print(first_text)
text=re.sub("[^a-zA-Z]"," ",first_text) #changing characters with space
text=text.lower()
# Out:
# I like eat delicious food. That's I'm cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"

# %%
import re ## Regular expression for deleting characters which are not letters.
first_sample = Data.Translated_Review[0] 
sample = re.sub("[^a-zA-Z]"," ",first_sample)
sample = sample.lower()
print("[{}] convert to \n[{}]".format(Data.Translated_Review[0],sample))
# Out:
# [I like eat delicious food. That's I'm cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"] convert to
# [i like eat delicious food  that s i m cooking food myself  case     best foods  helps lot  also  best before  shelf life  ]

# %%
print(type(sample))
# Out:
# <class 'str'>

# %%
## import libraries
import nltk  ## Natural Language Tool Kit
from nltk.corpus import stopwords

# %%
sample=nltk.word_tokenize(sample)
#print(sample)

# %%
sample = [word for word in sample if not word in set(stopwords.words("english"))]
print(sample)   ## drop unnecesarry words like it, I, you.
# Out:
# ['like', 'eat', 'delicious', 'food', 'cooking', 'food', 'case', 'best', 'foods', 'helps', 'lot', 'also', 'best', 'shelf', 'life']

# %%
lemma = nltk.WordNetLemmatizer()  ##We have already imported nltk.
sample = [ lemma.lemmatize(word) for word in sample]
sample = " ".join(sample)

## for this example there is no paragoge I cant show you but if there is -ed or -s or something like these,
## lemmatizer will drop them and returns stem of word

# %%
## Need to drop Na First
text_list=[]
for i in Data.Translated_Review:
    text=re.sub("[^a-zA-Z]"," ",i)
    text=text.lower()
    text=nltk.word_tokenize(text)
    lemma=nltk.WordNetLemmatizer()
    text=[lemma.lemmatize(word) for word in text]
    text=" ".join(text)
    text_list.append(text)

# %%
# show most used words in WordCloud
from wordcloud import WordCloud
plt.subplots(figsize=(12,12))
wordcloud=WordCloud(background_color="white",width=1024,height=768).generate(" ".join(text_list))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Using machine learning technique to predict the Sentiment of those reviews

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
max_features=1000
cou_vec=CountVectorizer(max_features=max_features)
y = Data.iloc[:,1].values
x= cou_vec.fit_transform(text_list).toarray()

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 10, random_state=42)
rf.fit(xtrain,ytrain)
print("accuracy: ",rf.score(xtest,ytest))
# Out:
# accuracy:  0.8936681806037937

# %%
# Show confusion matrix
y_pred=rf.predict(xtest)
y_true=ytest
from sklearn.metrics import confusion_matrix
import seaborn as sns
names=["Positive","Negative","Neutral"]
cm=confusion_matrix(y_true,y_pred)
f,ax=plt.subplots(figsize=(7,7))
sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %% [markdown]
# ###  Try with Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(xtrain,ytrain)
print("acc : ", nb.score(xtest,ytest))
# Out:
# acc :  0.5903018968741651

# %%
# Show confusion matrix
y_pred=nb.predict(xtest)
from sklearn.metrics import confusion_matrix
import seaborn as sns
names=["Positive","Negative","Neutral"]
cm=confusion_matrix(ytest,y_pred)
f,ax=plt.subplots(figsize=(7,7))
sns.heatmap(cm,annot=True,linewidth=.5,linecolor="r",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %% [markdown]
# ## NLP conclusion
#
# We found that Random Forest model have better performance and this model could be used for predicting comments sentiment categories when users write new comments in Google play store.

# %% [markdown]
# #### End of code
